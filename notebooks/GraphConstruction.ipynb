# %% [markdown]
# <a href="https://colab.research.google.com/github/loyoladesa/qoeprediction/blob/main/notebooks/GraphConstruction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Import Libraries

# %%
#libraries for data manipulation
import numpy as np
import pandas as pd

# %% [markdown]
# ## Constantes

# %%
path_rnp = '/content/drive/MyDrive/Seagate/RNP/dataset_set_2022/atraso_bidir/packet_count_lost_bidir/rj/rj_'

path_rnp_throughput_rj_sp = '/content/drive/MyDrive/Seagate/RNP/dataset_set_2022/banda_bbr/throughput/rj/throughput_rj_sp.csv'
path_rnp_throughput_rj = '/content/drive/MyDrive/Seagate/RNP/dataset_set_2022/banda_bbr/throughput/rj/throughput_rj_'
path_dataset_throughput_rj = '/content/drive/MyDrive/Seagate/RNP/dataset_set_2022/dataset/dataset_throughput_rj.csv'

path_rnp_throughput_sp_rj = '/content/drive/MyDrive/Seagate/RNP/dataset_set_2022/banda_bbr/throughput/sp/throughput_sp_rj.csv'
path_rnp_throughput_sp = '/content/drive/MyDrive/Seagate/RNP/dataset_set_2022/banda_bbr/throughput/sp/throughput_sp_'
path_dataset_throughput_sp = '/content/drive/MyDrive/Seagate/RNP/dataset_set_2022/dataset/dataset_throughput_sp.csv'

path_rnp_packet_retransmits_rj_sp = '/content/drive/MyDrive/Seagate/RNP/dataset_set_2022/banda_bbr/packet_retransmits/rj/packet_retransmits_rj_sp.csv'
path_rnp_packet_retransmits_rj = '/content/drive/MyDrive/Seagate/RNP/dataset_set_2022/banda_bbr/packet_retransmits/rj/packet_retransmits_rj_'
path_dataset_packet_retransmits_rj = '/content/drive/MyDrive/Seagate/RNP/dataset_set_2022/dataset/dataset_packet_retransmits_rj.csv'

path_rnp_packet_retransmits_sp_rj = '/content/drive/MyDrive/Seagate/RNP/dataset_set_2022/banda_bbr/packet_retransmits/sp/packet_retransmits_sp_rj.csv'
path_rnp_packet_retransmits_sp = '/content/drive/MyDrive/Seagate/RNP/dataset_set_2022/banda_bbr/packet_retransmits/sp/packet_retransmits_sp_'
path_dataset_packet_retransmits_sp = '/content/drive/MyDrive/Seagate/RNP/dataset_set_2022/dataset/dataset_packet_retransmits_sp.csv'






path_rnp_packet_count_lost_bidir_sp_rj = '/content/drive/MyDrive/Seagate/RNP/dataset_set_2022/atraso_bidir/packet_count_lost_bidir/sp/sp_rj.csv'
path_rnp_packet_count_lost_bidir_rj_sp = '/content/drive/MyDrive/Seagate/RNP/dataset_set_2022/atraso_bidir/packet_count_lost_bidir/rj/rj_sp.csv'

path_rnp_throughput_ac_al = '/content/drive/MyDrive/Seagate/RNP/dataset_set_2022/banda_bbr/throughput/ac/throughput_ac_al.csv'
path_rnp_packet_retransmits_ac_al = '/content/drive/MyDrive/Seagate/RNP/dataset_set_2022/banda_bbr/packet_retransmits/ac/packet_retransmits_ac_al.csv'


path_packet = '/content/drive/MyDrive/Seagate/RNP/dataset/packet/ac_al.csv'

pop_destino = ['am', 'ap', 'ba', 'ce', 'df', 'es', 'go', 'ma', 'mg', 'ms', 'mt', 'pa', 'pb', 'pe','pi', 'pr', 'rn', 'ro', 'rr', 'rs', 'sc', 'se', 'sp', 'to']

# %% [markdown]
# ## Load Data

# %%
df_sp_rj = pd.read_csv(path_rnp_packet_count_lost_bidir_sp_rj,sep=";")
df_sp_rj
# Out:
#                 TimeStamp  Latitude  Longitude  Valor  POP_origem  \
# 0     2022-09-01 00:00:09 -23.55613  -46.72961      0          26
# 1     2022-09-01 00:04:26 -23.55613  -46.72961      0          26
# 2     2022-09-01 00:09:14 -23.55613  -46.72961      0          26
# 3     2022-09-01 00:15:04 -23.55613  -46.72961      0          26
# 4     2022-09-01 00:22:35 -23.55613  -46.72961      0          26
# ...                   ...       ...        ...    ...         ...
# 8091  2022-09-30 23:41:06 -23.55613  -46.72961      0          26
# 8092  2022-09-30 23:43:45 -23.55613  -46.72961      0          26
# 8093  2022-09-30 23:50:59 -23.55613  -46.72961      0          26
# 8094  2022-09-30 23:56:36 -23.55613  -46.72961      0          26
# 8095  2022-09-30 23:57:00 -23.55613  -46.72961      0          26
#
#       POP_destino  cod_metrica
# 0              19           21
# 1              19           21
# 2              19           21
# 3              19           21
# ...

# %%
df_rj_sp = pd.read_csv(path_rnp_packet_count_lost_bidir_rj_sp,sep=";")
df_rj_sp
# Out:
#                 TimeStamp  Latitude  Longitude  Valor  POP_origem  \
# 0     2022-09-01 00:00:28 -22.95416  -43.17444      0          19
# 1     2022-09-01 00:03:12 -22.95416  -43.17444      0          19
# 2     2022-09-01 00:12:02 -22.95416  -43.17444      0          19
# 3     2022-09-01 00:17:08 -22.95416  -43.17444      0          19
# 4     2022-09-01 00:18:08 -22.95416  -43.17444      0          19
# ...                   ...       ...        ...    ...         ...
# 8118  2022-09-30 23:36:14 -22.95416  -43.17444      0          19
# 8119  2022-09-30 23:40:02 -22.95416  -43.17444      0          19
# 8120  2022-09-30 23:48:45 -22.95416  -43.17444      0          19
# 8121  2022-09-30 23:50:15 -22.95416  -43.17444      0          19
# 8122  2022-09-30 23:55:18 -22.95416  -43.17444      0          19
#
#       POP_destino  cod_metrica
# 0              26           21
# 1              26           21
# 2              26           21
# 3              26           21
# ...

# %%
df_throughput_rj_sp = pd.read_csv(path_rnp_throughput_rj_sp,sep=";")
df_throughput_rj_sp
# Out:
#               TimeStamp  Latitude  Longitude    Valor  POP_origem  \
# 0   2022-09-01 01:33:50 -22.95416  -43.17444  4516581          19
# 1   2022-09-01 06:40:08 -22.95416  -43.17444  3295922          19
# 2   2022-09-01 16:37:44 -22.95416  -43.17444  4968171          19
# 3   2022-09-01 22:53:39 -22.95416  -43.17444  5570892          19
# 4   2022-09-03 14:14:42 -22.95416  -43.17444  4442622          19
# ..                  ...       ...        ...      ...         ...
# 58  2022-09-27 15:37:27 -22.95416  -43.17444  3172003          19
# 59  2022-09-27 21:09:12 -22.95416  -43.17444  5115441          19
# 60  2022-09-28 03:00:39 -22.95416  -43.17444  5752609          19
# 61  2022-09-29 10:56:55 -22.95416  -43.17444  2608883          19
# 62  2022-09-30 18:25:40 -22.95416  -43.17444  4605515          19
#
#     POP_destino  cod_metrica
# 0            26           77
# 1            26           77
# 2            26           77
# 3            26           77
# ...

# %%
df_throughput_ac_al = pd.read_csv(path_rnp_throughput_ac_al,sep=";")
df_throughput_ac_al
# Out:
#               TimeStamp  Latitude  Longitude   Valor  POP_origem  POP_destino  \
# 0   2022-09-01 04:16:44   -9.9563  -67.86543  915296           1            2
# 1   2022-09-01 12:30:58   -9.9563  -67.86543  877289           1            2
# 2   2022-09-01 19:32:24   -9.9563  -67.86543  908235           1            2
# 3   2022-09-01 20:39:16   -9.9563  -67.86543  894068           1            2
# 4   2022-09-02 00:30:46   -9.9563  -67.86543  915774           1            2
# ..                  ...       ...        ...     ...         ...          ...
# 85  2022-09-29 14:31:28   -9.9563  -67.86543  888408           1            2
# 86  2022-09-29 23:53:58   -9.9563  -67.86543  882744           1            2
# 87  2022-09-30 01:24:24   -9.9563  -67.86543  904713           1            2
# 88  2022-09-30 18:47:32   -9.9563  -67.86543  904450           1            2
# 89  2022-09-30 21:28:22   -9.9563  -67.86543  880699           1            2
#
#     cod_metrica
# ...

# %%
df_packet_retransmits_ac_al = pd.read_csv(path_rnp_packet_retransmits_ac_al,sep=";")
df_packet_retransmits_ac_al
# Out:
#               TimeStamp  Latitude  Longitude  Valor  POP_origem  POP_destino  \
# 0   2022-09-01 04:16:44   -9.9563  -67.86543    439           1            2
# 1   2022-09-01 12:30:58   -9.9563  -67.86543     72           1            2
# 2   2022-09-01 19:32:24   -9.9563  -67.86543    409           1            2
# 3   2022-09-01 20:39:16   -9.9563  -67.86543    380           1            2
# 4   2022-09-02 00:30:46   -9.9563  -67.86543    494           1            2
# ..                  ...       ...        ...    ...         ...          ...
# 85  2022-09-29 14:31:28   -9.9563  -67.86543    546           1            2
# 86  2022-09-29 23:53:58   -9.9563  -67.86543    162           1            2
# 87  2022-09-30 01:24:24   -9.9563  -67.86543    482           1            2
# 88  2022-09-30 18:47:32   -9.9563  -67.86543    539           1            2
# 89  2022-09-30 21:28:22   -9.9563  -67.86543    224           1            2
#
#     cod_metrica
# 0            71
# ...

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Dataset_1

# %%
dataset = df_rj_sp[['TimeStamp']]
dataset['Metrica'] = 'packet_count_lost_bidir'
dataset['Origem'] = 'rj'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for destino in pop_destino:
  path_destino = path_rnp + destino + '.csv'
  df_destino = pd.read_csv(path_destino,sep=";")
  dataset[destino] = df_destino[['Valor']]
  mean_value = dataset[destino].mean()
  dataset[destino].fillna(value=mean_value, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
dataset
# Out:
#                 TimeStamp                  Metrica Origem  am  ap        ba  \
# 0     2022-09-01 00:00:28  packet_count_lost_bidir     rj   0   0  0.000000
# 1     2022-09-01 00:03:12  packet_count_lost_bidir     rj   0   0  0.000000
# 2     2022-09-01 00:12:02  packet_count_lost_bidir     rj   0   0  0.000000
# 3     2022-09-01 00:17:08  packet_count_lost_bidir     rj   0   0  0.000000
# 4     2022-09-01 00:18:08  packet_count_lost_bidir     rj   0   0  0.000000
# ...                   ...                      ...    ...  ..  ..       ...
# 8118  2022-09-30 23:36:14  packet_count_lost_bidir     rj   0   0  0.041092
# 8119  2022-09-30 23:40:02  packet_count_lost_bidir     rj   0   0  0.041092
# 8120  2022-09-30 23:48:45  packet_count_lost_bidir     rj   0   0  0.041092
# 8121  2022-09-30 23:50:15  packet_count_lost_bidir     rj   0   0  0.041092
# 8122  2022-09-30 23:55:18  packet_count_lost_bidir     rj   0   0  0.041092
#
# ...

# %% [markdown]
# ### Dataset_2

# %%
dataset_2 = df_throughput_ac_al[['TimeStamp']]
dataset_2['Origem'] = 'ac'
dataset_2['Destino'] = 'al'
dataset_2['Throughput'] = df_throughput_ac_al[['Valor']]
dataset_2['Packet_retransmits'] = df_packet_retransmits_ac_al[['Valor']]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dataset_2
# Out:
#               TimeStamp Origem Destino  Throughput  Packet_retransmits
# 0   2022-09-01 04:16:44     ac      al      915296                 439
# 1   2022-09-01 12:30:58     ac      al      877289                  72
# 2   2022-09-01 19:32:24     ac      al      908235                 409
# 3   2022-09-01 20:39:16     ac      al      894068                 380
# 4   2022-09-02 00:30:46     ac      al      915774                 494
# ..                  ...    ...     ...         ...                 ...
# 85  2022-09-29 14:31:28     ac      al      888408                 546
# 86  2022-09-29 23:53:58     ac      al      882744                 162
# 87  2022-09-30 01:24:24     ac      al      904713                 482
# 88  2022-09-30 18:47:32     ac      al      904450                 539
# 89  2022-09-30 21:28:22     ac      al      880699                 224
#
# [90 rows x 5 columns]

# %% [markdown]
# ## Causalidade

# %% [markdown]
# ### Calcular Causalidade

# %%
from statsmodels.tsa.stattools import grangercausalitytests
def calcularCausalidade(a,b):
  array = pd.DataFrame()
  array[0] = b
  array[1] = a
  array.dropna()
  try:
      #perform Granger-Causality test
      causalidade_test = grangercausalitytests(array, maxlag=[3])
      tupla = causalidade_test[3]
      testes = tupla[0]
      p_values = testes['params_ftest']
      if (p_values[1] < 0.05):
        return True
      return False
  except Exception as e:
      print("Exception: ",e)
      return False

# %% [markdown]
# ### Teste Não Causalidade

# %%
array = dataset[['ba', 'sp']]
print(type(array))
array
# Out:
# <class 'pandas.core.frame.DataFrame'>
#             ba  sp
# 0     0.000000   0
# 1     0.000000   0
# 2     0.000000   0
# 3     0.000000   0
# 4     0.000000   0
# ...        ...  ..
# 8118  0.041092   0
# 8119  0.041092   0
# 8120  0.041092   0
# 8121  0.041092   0
# 8122  0.041092   0
#
# [8123 rows x 2 columns]

# %%
causalidade = 'Não Existe Causalidade!' 
existeCausalidade = calcularCausalidade(array[['sp']],array[['ba']])
if (existeCausalidade):
  causalidade = 'Existe Causalidade!'
print()
print(causalidade)
# Out:
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1868  , p=0.9054  , df_denom=8113, df_num=3
# ssr based chi2 test:   chi2=0.5609  , p=0.9053  , df=3
# likelihood ratio test: chi2=0.5609  , p=0.9053  , df=3
# parameter F test:         F=0.1868  , p=0.9054  , df_denom=8113, df_num=3
#
# Não Existe Causalidade!

# %% [markdown]
# ### Teste Causalidade

# %%
array = dataset_2[['Packet_retransmits','Throughput']]
print(type(array))
array
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     Packet_retransmits  Throughput
# 0                  439      915296
# 1                   72      877289
# 2                  409      908235
# 3                  380      894068
# 4                  494      915774
# ..                 ...         ...
# 85                 546      888408
# 86                 162      882744
# 87                 482      904713
# 88                 539      904450
# 89                 224      880699
#
# [90 rows x 2 columns]

# %%
causalidade = 'Não Existe Causalidade!' 
existeCausalidade = calcularCausalidade(array[['Throughput']],array[['Packet_retransmits']])
if (existeCausalidade):
  causalidade = 'Existe Causalidade!'
print()
print(causalidade)
# Out:
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.7513  , p=0.0480  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=8.9762  , p=0.0296  , df=3
# likelihood ratio test: chi2=8.5427  , p=0.0360  , df=3
# parameter F test:         F=2.7513  , p=0.0480  , df_denom=80, df_num=3
#
# Existe Causalidade!

# %% [markdown]
# ### Time Series Plot

# %%
import matplotlib.pyplot as plt
import datetime
import numpy as np
import pandas as pd

#define data
df = df_sp_rj

df2 = df_rj_sp

# %%
df
# Out:
#                 TimeStamp  Latitude  Longitude  Valor  POP_origem  \
# 0     2022-09-01 00:00:09 -23.55613  -46.72961      0          26
# 1     2022-09-01 00:04:26 -23.55613  -46.72961      0          26
# 2     2022-09-01 00:09:14 -23.55613  -46.72961      0          26
# 3     2022-09-01 00:15:04 -23.55613  -46.72961      0          26
# 4     2022-09-01 00:22:35 -23.55613  -46.72961      0          26
# ...                   ...       ...        ...    ...         ...
# 8091  2022-09-30 23:41:06 -23.55613  -46.72961      0          26
# 8092  2022-09-30 23:43:45 -23.55613  -46.72961      0          26
# 8093  2022-09-30 23:50:59 -23.55613  -46.72961      0          26
# 8094  2022-09-30 23:56:36 -23.55613  -46.72961      0          26
# 8095  2022-09-30 23:57:00 -23.55613  -46.72961      0          26
#
#       POP_destino  cod_metrica
# 0              19           21
# 1              19           21
# 2              19           21
# 3              19           21
# ...

# %%
#plot both time series
plt.plot(df.TimeStamp, df.Valor, label='sp_rj', linewidth=3)
plt.plot(df2.TimeStamp, df2.Valor, color='red', label='rj_sp', linewidth=3)

#add title and axis labels
plt.title('Packet_Count_lost by Timestamp')
plt.xlabel('Timestamp')
plt.ylabel('Valor')

#add legend
plt.legend()

#display plot
plt.show()

# %% [markdown]
# ## Preliminary Graph Construction

# %% [markdown]
# ### Dataset

# %% [markdown]
# #### Throughput RJ

# %%
dataset_throughput_rj = pd.read_csv(path_rnp_throughput_rj_sp,sep=";")

# %%
dataset_throughput_rj = dataset_throughput_rj[['TimeStamp']]
dataset_throughput_rj['Metrica'] = 'Throughput'
dataset_throughput_rj['Origem'] = 'rj'

# %%
for destino in pop_destino:
  path_destino = path_rnp_throughput_rj + destino + '.csv'
  df_destino = pd.read_csv(path_destino,sep=";")
  dataset_throughput_rj[destino] = df_destino[['Valor']]
  mean_value = dataset_throughput_rj[destino].mean()
  dataset_throughput_rj[destino].fillna(value=mean_value, inplace=True)
  dataset_throughput_rj[destino].fillna(value=0, inplace=True)

# %%
dataset_throughput_rj
# Out:
#               TimeStamp     Metrica Origem      am      ap       ba      ce  \
# 0   2022-09-01 01:33:50  Throughput     rj  845572  820199  7840729  866019
# 1   2022-09-01 06:40:08  Throughput     rj  847565  787375  3424706  864759
# 2   2022-09-01 16:37:44  Throughput     rj  803419  831836  3847770  861982
# 3   2022-09-01 22:53:39  Throughput     rj  355415  808513  7283799  854601
# 4   2022-09-03 14:14:42  Throughput     rj  862925  895327  6807939  842006
# ..                  ...         ...    ...     ...     ...      ...     ...
# 58  2022-09-27 15:37:27  Throughput     rj  868746  866806  8286743  878338
# 59  2022-09-27 21:09:12  Throughput     rj  234217  875721  8287612  826594
# 60  2022-09-28 03:00:39  Throughput     rj  499071  202689  5980338  890871
# 61  2022-09-29 10:56:55  Throughput     rj  519831  886833  1772833  885312
# 62  2022-09-30 18:25:40  Throughput     rj  886258  135948  2610367  862297
#
# ...

# %%
dataset_throughput_rj.to_csv(path_dataset_throughput_rj,index=False)

# %% [markdown]
# #### Troughput SP

# %%
dataset_throughput_sp = pd.read_csv(path_rnp_throughput_sp_rj,sep=";")

# %%
dataset_throughput_sp = dataset_throughput_sp[['TimeStamp']]
dataset_throughput_sp['Metrica'] = 'Throughput'
dataset_throughput_sp['Origem'] = 'sp'

# %%
for destino in pop_destino:
  path_destino = path_rnp_throughput_sp + destino + '.csv'
  df_destino = pd.read_csv(path_destino,sep=";")
  dataset_throughput_sp[destino] = df_destino[['Valor']]
  mean_value = dataset_throughput_sp[destino].mean()
  dataset_throughput_sp[destino].fillna(value=mean_value, inplace=True)
  dataset_throughput_sp[destino].fillna(value=0, inplace=True)

# %%
dataset_throughput_sp
# Out:
#               TimeStamp     Metrica Origem      am      ap       ba      ce  \
# 0   2022-09-01 15:20:39  Throughput     sp  892913  847440  2264074  896221
# 1   2022-09-01 17:30:12  Throughput     sp  867960  882590  2480530  899888
# 2   2022-09-01 23:21:00  Throughput     sp  893016  888353  2778045  900831
# 3   2022-09-03 01:13:07  Throughput     sp  641013  890821  1771728  903085
# 4   2022-09-04 15:05:50  Throughput     sp  885625  572681  1670398  901046
# ..                  ...         ...    ...     ...     ...      ...     ...
# 56  2022-09-27 11:05:42  Throughput     sp  884526  894858  1867567  895905
# 57  2022-09-27 15:24:07  Throughput     sp  884477  891447  1535117  904608
# 58  2022-09-27 18:24:30  Throughput     sp  884055  883430  2266600  890557
# 59  2022-09-27 23:49:38  Throughput     sp  869744  887096  3304959  900885
# 60  2022-09-28 14:56:04  Throughput     sp  906809  425775  2422081  901880
#
# ...

# %%
dataset_throughput_sp.to_csv(path_dataset_throughput_sp,index=False)

# %% [markdown]
# #### Packet_Retransmits RJ

# %%
dataset_packet_retransmits_rj = pd.read_csv(path_rnp_packet_retransmits_rj_sp,sep=";")

# %%
dataset_packet_retransmits_rj = dataset_packet_retransmits_rj[['TimeStamp']]
dataset_packet_retransmits_rj['Metrica'] = 'Packet Retransmits'
dataset_packet_retransmits_rj['Origem'] = 'rj'

# %%
for destino in pop_destino:
  path_destino = path_rnp_packet_retransmits_rj + destino + '.csv'
  df_destino = pd.read_csv(path_destino,sep=";")
  dataset_packet_retransmits_rj[destino] = df_destino[['Valor']]
  mean_value = dataset_packet_retransmits_rj[destino].mean()
  dataset_packet_retransmits_rj[destino].fillna(value=mean_value, inplace=True)
  dataset_packet_retransmits_rj[destino].fillna(value=0, inplace=True)

# %%
dataset_packet_retransmits_rj

# %%
dataset_packet_retransmits_rj.to_csv(path_dataset_packet_retransmits_rj,index=False)

# %% [markdown]
# #### Packet_Retransmits SP

# %%
dataset_packet_retransmits_sp = pd.read_csv(path_rnp_packet_retransmits_sp_rj,sep=";")

# %%
dataset_packet_retransmits_sp = dataset_packet_retransmits_sp[['TimeStamp']]
dataset_packet_retransmits_sp['Metrica'] = 'Packet Retransmits'
dataset_packet_retransmits_sp['Origem'] = 'sp'

# %%
for destino in pop_destino:
  path_destino = path_rnp_packet_retransmits_sp + destino + '.csv'
  df_destino = pd.read_csv(path_destino,sep=";")
  dataset_packet_retransmits_sp[destino] = df_destino[['Valor']]
  mean_value = dataset_packet_retransmits_sp[destino].mean()
  dataset_packet_retransmits_sp[destino].fillna(value=mean_value, inplace=True)
  dataset_packet_retransmits_sp[destino].fillna(value=0, inplace=True)

# %%
dataset_packet_retransmits_sp

# %%
dataset_packet_retransmits_sp.to_csv(path_dataset_packet_retransmits_sp,index=False)

# %% [markdown]
# ### Stage 1

# %%
dataset_throughput_rj = pd.read_csv(path_dataset_throughput_rj,sep=",")
dataset_throughput_sp = pd.read_csv(path_dataset_throughput_sp,sep=",")
dataset_packet_retransmits_sp = pd.read_csv(path_dataset_packet_retransmits_sp,sep=",")
dataset_packet_retransmits_rj = pd.read_csv(path_dataset_packet_retransmits_rj,sep=",")

# %%
dataset_throughput_rj.dropna()
dataset_throughput_sp.dropna()
dataset_packet_retransmits_rj.dropna()
dataset_packet_retransmits_sp.dropna()
# Out:
#               TimeStamp             Metrica Origem      am      ap      ba  \
# 0   2022-09-01 15:20:39  Packet Retransmits     sp   39586   38707  165567
# 1   2022-09-01 17:30:12  Packet Retransmits     sp   49770   38427  188894
# 2   2022-09-01 23:21:00  Packet Retransmits     sp   40905   42374  160854
# 3   2022-09-03 01:13:07  Packet Retransmits     sp  132882   39347   90894
# 4   2022-09-04 15:05:50  Packet Retransmits     sp   36871  138089  154731
# ..                  ...                 ...    ...     ...     ...     ...
# 56  2022-09-27 11:05:42  Packet Retransmits     sp   44914   36983  138669
# 57  2022-09-27 15:24:07  Packet Retransmits     sp   46337   40298  188346
# 58  2022-09-27 18:24:30  Packet Retransmits     sp   45378   37880  198827
# 59  2022-09-27 23:49:38  Packet Retransmits     sp   45847   39811  139511
# 60  2022-09-28 14:56:04  Packet Retransmits     sp   33128   70549  188601
#
# ...

# %%
alvo = dataset_packet_retransmits_rj[['sp']]
alvo
# Out:
#        sp
# 0       0
# 1     956
# 2    4649
# 3    9926
# 4   40668
# ..    ...
# 58  11944
# 59  52546
# 60      0
# 61   1428
# 62      2
#
# [63 rows x 1 columns]

# %%
S = []
for destino in pop_destino:
  S.append(dataset_throughput_sp[[destino]])
  S.append(dataset_packet_retransmits_rj[[destino]])
  S.append(dataset_packet_retransmits_sp[[destino]])
  if (destino != 'sp'):
    S.append(dataset_throughput_rj[[destino]])

# %%
len(S)
# Out:
# 95

# %%
print(calcularCausalidade(S[0],S[20]))
# Out:
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.5293  , p=0.2176  , df_denom=53, df_num=3
# ssr based chi2 test:   chi2=5.1939  , p=0.1581  , df=3
# likelihood ratio test: chi2=4.9813  , p=0.1732  , df=3
# parameter F test:         F=1.5293  , p=0.2176  , df_denom=53, df_num=3
# False

# %%
import networkx as nx
G = nx.DiGraph()

n = len(S)

for i in range(n):
  for j in range(n):
    print("i =",i,"j = ",j)
    array = pd.DataFrame()
    array[0] = S[i]
    array[1] = S[j] 
    array.dropna()
    if(i != j):
      existeCausalidade = calcularCausalidade(array[0],array[1])
      if (existeCausalidade):
          G.add_edge(i, j)
      existeCausalidade = calcularCausalidade(array[0],alvo)
      if (existeCausalidade):
          G.add_edge(i, 'C')
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1455  , p=0.3393  , df_denom=53, df_num=3
# ssr based chi2 test:   chi2=3.8903  , p=0.2736  , df=3
# likelihood ratio test: chi2=3.7694  , p=0.2875  , df=3
# parameter F test:         F=1.1455  , p=0.3393  , df_denom=53, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.0000  , p=1.0000  , df_denom=56, df_num=3
# ssr based chi2 test:   chi2=0.0000  , p=1.0000  , df=3
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=3
# parameter F test:         F=1.6488  , p=0.1885  , df_denom=56, df_num=3
# i = 89 j =  46
# Exception:  x contains NaN or inf values.
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.0000  , p=1.0000  , df_denom=56, df_num=3
# ssr based chi2 test:   chi2=0.0000  , p=1.0000  , df=3
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=3
# ...

# %%
print(G.nodes()) # [4, 5]

n_vertices = G.number_of_nodes()
n_arestas = G.number_of_edges()
print('vertices: ', n_vertices, '\narestas: ', n_arestas)

nx.draw(G, with_labels=True)
# Out:
# [0, 6, 21, 22, 25, 46, 2, 24, 60, 62, 77, 93, 4, 5, 13, 14, 86, 'C', 15, 89, 8, 10, 20, 23, 30, 41, 43, 50, 68, 72, 78, 7, 35, 47, 65, 67, 85, 9, 11, 69, 71, 28, 84, 92, 12, 3, 44, 54, 75, 91, 70, 1, 51, 64, 87, 36, 26, 63, 81, 48, 29, 37, 39, 53, 94, 83, 31, 32, 33, 55, 34, 79, 27, 38, 45, 82, 40, 42, 74, 80, 49, 52, 66, 73, 61, 76]
# vertices:  86
# arestas:  352

# %% [markdown]
# ##### Stage 1 - 23

# %%
S = []
for destino in pop_destino:
  #S.append(dataset_throughput_sp[[destino]])
  #S.append(dataset_packet_retransmits_rj[[destino]])
  #S.append(dataset_packet_retransmits_sp[[destino]])
  if (destino != 'sp'):
    S.append(dataset_throughput_rj[[destino]])

# %%
len(S)
# Out:
# 23

# %%
import networkx as nx
G = nx.DiGraph()

n = len(S)

for i in range(n):
  for j in range(n):
    print("i =",i,"j = ",j)
    array = pd.DataFrame()
    array[0] = S[i]
    array[1] = S[j] 
    array.dropna()
    if(i != j):
      existeCausalidade = calcularCausalidade(array[0],array[1])
      if (existeCausalidade):
          G.add_edge(i, j)
      existeCausalidade = calcularCausalidade(array[0],alvo)
      if (existeCausalidade):
          G.add_edge(i, 'C')
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1017  , p=0.9587  , df_denom=53, df_num=3
# ssr based chi2 test:   chi2=0.3456  , p=0.9512  , df=3
# likelihood ratio test: chi2=0.3446  , p=0.9514  , df=3
# parameter F test:         F=0.1017  , p=0.9587  , df_denom=53, df_num=3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1862  , p=0.9053  , df_denom=53, df_num=3
# ssr based chi2 test:   chi2=0.6325  , p=0.8889  , df=3
# likelihood ratio test: chi2=0.6292  , p=0.8897  , df=3
# parameter F test:         F=0.1862  , p=0.9053  , df_denom=53, df_num=3
# i = 7 j =  6
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.2829  , p=0.2898  , df_denom=53, df_num=3
# ssr based chi2 test:   chi2=4.3570  , p=0.2254  , df=3
# likelihood ratio test: chi2=4.2061  , p=0.2401  , df=3
# ...

# %%
print(G.nodes()) # [4, 5]

n_vertices = G.number_of_nodes()
n_arestas = G.number_of_edges()
print('vertices: ', n_vertices, '\narestas: ', n_arestas)

nx.draw(G, with_labels=True)
# Out:
# [5, 12, 17, 21, 7, 9, 16, 22, 8, 0, 19, 20, 6, 11, 13, 18, 15, 'C']
# vertices:  18
# arestas:  26

# %% [markdown]
# ### Stage 2

# %%
import networkx as nx
n = len(S)

for i in range(n):
  for j in range(n):
    print("i =",i,"j = ",j)
    array = pd.DataFrame()
    array[0] = S[i]
    array[1] = S[j] 
    array.dropna()
    if(i != j):
      existeCausalidade_i_c = calcularCausalidade(array[0],alvo)
      if (existeCausalidade_i_c):
          existeCausalidade_j_c = calcularCausalidade(array[1],alvo)
          if (existeCausalidade_j_c):
              existeCausalidade_i_j = calcularCausalidade(array[0],array[1])
              if (existeCausalidade_i_j):
                  G.remove_edge(i, 'C')
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# ssr based F test:         F=0.3754  , p=0.7711  , df_denom=53, df_num=3
# ssr based chi2 test:   chi2=1.2751  , p=0.7351  , df=3
# likelihood ratio test: chi2=1.2617  , p=0.7382  , df=3
# parameter F test:         F=0.3754  , p=0.7711  , df_denom=53, df_num=3
# i = 83 j =  82
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3754  , p=0.7711  , df_denom=53, df_num=3
# ssr based chi2 test:   chi2=1.2751  , p=0.7351  , df=3
# likelihood ratio test: chi2=1.2617  , p=0.7382  , df=3
# parameter F test:         F=0.3754  , p=0.7711  , df_denom=53, df_num=3
# i = 83 j =  83
# i = 83 j =  84
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3754  , p=0.7711  , df_denom=53, df_num=3
# ssr based chi2 test:   chi2=1.2751  , p=0.7351  , df=3
# likelihood ratio test: chi2=1.2617  , p=0.7382  , df=3
# parameter F test:         F=0.3754  , p=0.7711  , df_denom=53, df_num=3
# ...

# %%
print(G.nodes()) # [4, 5]

n_vertices = G.number_of_nodes()
n_arestas = G.number_of_edges()
print('vertices: ', n_vertices, '\narestas: ', n_arestas)
# Out:
# [0, 6, 21, 22, 25, 46, 2, 24, 60, 62, 77, 93, 4, 5, 13, 14, 86, 'C', 15, 89, 8, 10, 20, 23, 30, 41, 43, 50, 68, 72, 78, 7, 35, 47, 65, 67, 85, 9, 11, 69, 71, 28, 84, 92, 12, 3, 44, 54, 75, 91, 70, 1, 51, 64, 87, 36, 26, 63, 81, 48, 29, 37, 39, 53, 94, 83, 31, 32, 33, 55, 34, 79, 27, 38, 45, 82, 40, 42, 74, 80, 49, 52, 66, 73, 61, 76]
# vertices:  86
# arestas:  351

# %%
nx.draw(G, with_labels=True)

# %% [markdown]
# ##### Stage 2 -23

# %%
import networkx as nx
n = len(S)

for i in range(n):
  for j in range(n):
    print("i =",i,"j = ",j)
    array = pd.DataFrame()
    array[0] = S[i]
    array[1] = S[j] 
    array.dropna()
    if(i != j):
      existeCausalidade_i_c = calcularCausalidade(array[0],alvo)
      if (existeCausalidade_i_c):
          existeCausalidade_j_c = calcularCausalidade(array[1],alvo)
          if (existeCausalidade_j_c):
              existeCausalidade_i_j = calcularCausalidade(array[0],array[1])
              if (existeCausalidade_i_j):
                  G.remove_edge(i, 'C')
# Out:
# i = 0 j =  0
# i = 0 j =  1
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.8394  , p=0.1512  , df_denom=53, df_num=3
# ssr based chi2 test:   chi2=6.2471  , p=0.1002  , df=3
# likelihood ratio test: chi2=5.9428  , p=0.1144  , df=3
# parameter F test:         F=1.8394  , p=0.1512  , df_denom=53, df_num=3
# i = 0 j =  2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.8394  , p=0.1512  , df_denom=53, df_num=3
# ssr based chi2 test:   chi2=6.2471  , p=0.1002  , df=3
# likelihood ratio test: chi2=5.9428  , p=0.1144  , df=3
# parameter F test:         F=1.8394  , p=0.1512  , df_denom=53, df_num=3
# i = 0 j =  3
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.8394  , p=0.1512  , df_denom=53, df_num=3
# ssr based chi2 test:   chi2=6.2471  , p=0.1002  , df=3
# likelihood ratio test: chi2=5.9428  , p=0.1144  , df=3
# parameter F test:         F=1.8394  , p=0.1512  , df_denom=53, df_num=3
# ...

# %%
print(G.nodes()) # [4, 5]

n_vertices = G.number_of_nodes()
n_arestas = G.number_of_edges()
print('vertices: ', n_vertices, '\narestas: ', n_arestas)
# Out:
# [5, 12, 17, 21, 7, 9, 16, 22, 8, 0, 19, 20, 6, 11, 13, 18, 15, 'C']
# vertices:  18
# arestas:  26

# %%
nx.draw(G, with_labels=True)
